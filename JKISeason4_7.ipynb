# %% [markdown]
# <a href="https://colab.research.google.com/github/andrecarva/Just-KNIME-it-/blob/main/JKISeason4_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('players_data-2024_2025.csv')
display(df.head())
# Out:
#    Rk             Player   Nation    Pos        Squad                Comp  \
# 0   1         Max Aarons  eng ENG     DF  Bournemouth  eng Premier League
# 1   2         Max Aarons  eng ENG     MF     Valencia          es La Liga
# 2   3     Rodrigo Abajas   es ESP     DF     Valencia          es La Liga
# 3   4     James Abankwah   ie IRL  DF,MF      Udinese          it Serie A
# 4   5  Keyliane Abdallah   fr FRA     FW    Marseille          fr Ligue 1
#
#     Age    Born  MP  Starts  ...  Att (GK)  Thr  Launch%  AvgLen  Opp  Stp  \
# 0  25.0  2000.0   3       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 1  25.0  2000.0   1       0  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 2  21.0  2003.0   1       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 3  21.0  2004.0   6       0  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 4  18.0  2006.0   1       0  ...       NaN  NaN      NaN     NaN  NaN  NaN
#
#    Stp%  #OPA  #OPA/90  AvgDist
# 0   NaN   NaN      NaN      NaN
# 1   NaN   NaN      NaN      NaN
# 2   NaN   NaN      NaN      NaN
# 3   NaN   NaN      NaN      NaN
# 4   NaN   NaN      NaN      NaN
#
# [5 rows x 267 columns]

# %%
# Calculate the percentage of missing values for each column
missing_percentages = df.isnull().sum() / len(df) * 100

# Identify columns with more than 10% missing values
columns_to_drop = missing_percentages[missing_percentages > 10].index

# Drop the identified columns
df = df.drop(columns=columns_to_drop)

# Display the first few rows and the shape of the updated DataFrame
display(df.head())
print(f"Shape of the DataFrame after dropping columns: {df.shape}")
# Out:
#    Rk             Player   Nation    Pos        Squad                Comp  \
# 0   1         Max Aarons  eng ENG     DF  Bournemouth  eng Premier League
# 1   2         Max Aarons  eng ENG     MF     Valencia          es La Liga
# 2   3     Rodrigo Abajas   es ESP     DF     Valencia          es La Liga
# 3   4     James Abankwah   ie IRL  DF,MF      Udinese          it Serie A
# 4   5  Keyliane Abdallah   fr FRA     FW    Marseille          fr Ligue 1
#
#     Age    Born  MP  Starts  ...  Crs_stats_misc  Int_stats_misc  \
# 0  25.0  2000.0   3       1  ...               2               1
# 1  25.0  2000.0   1       0  ...               2               0
# 2  21.0  2003.0   1       1  ...               1               1
# 3  21.0  2004.0   6       0  ...               0               1
# 4  18.0  2006.0   1       0  ...               0               0
#
#    TklW_stats_misc  PKwon  PKcon  OG  Recov  Won  Lost_stats_misc  Won%
# 0                2      0      0   0      7    0                0   NaN
# 1                1      0      0   0      4    0                0   NaN
# 2                2      0      0   0      2    0                1   0.0
# 3                2      0      0   0      7    2                2  50.0
# 4                1      0      0   0      0    0                0   NaN
#
# [5 rows x 204 columns]
# Shape of the DataFrame after dropping columns: (2657, 204)

# %%
# List of columns to keep
columns_to_keep = ['Player', 'Nation', 'Pos', 'Squad', 'Age', 'MP', 'Starts', '90s', 'Gls', 'Ast', 'TklW', 'Tkl+Int', 'KP', 'Cmp%']

# Create a new DataFrame with only the specified columns
df = df[columns_to_keep]

# Display the first few rows and the shape of the updated DataFrame
display(df.head())
print(f"Shape of the DataFrame after keeping selected columns: {df.shape}")
# Out:
#               Player   Nation    Pos        Squad   Age  MP  Starts  90s  Gls  \
# 0         Max Aarons  eng ENG     DF  Bournemouth  25.0   3       1  1.0    0
# 1         Max Aarons  eng ENG     MF     Valencia  25.0   1       0  0.3    0
# 2     Rodrigo Abajas   es ESP     DF     Valencia  21.0   1       1  0.7    0
# 3     James Abankwah   ie IRL  DF,MF      Udinese  21.0   6       0  1.0    0
# 4  Keyliane Abdallah   fr FRA     FW    Marseille  18.0   1       0  0.0    0
#
#    Ast  TklW  Tkl+Int  KP   Cmp%
# 0    0     2        3   0   79.4
# 1    0     1        1   0   77.8
# 2    0     2        4   0   58.6
# 3    0     2        5   0   78.3
# 4    0     1        1   0  100.0
# Shape of the DataFrame after keeping selected columns: (2657, 14)

# %%
# Filter rows where Age is less than 20
df_under_20 = df[df['Age'] <= 20]

# Display the first few rows and the shape of the filtered DataFrame
display(df_under_20.head())
print(f"Shape of the DataFrame after filtering by age: {df_under_20.shape}")
# Out:
#                Player   Nation    Pos           Squad   Age  MP  Starts  90s  \
# 4   Keyliane Abdallah   fr FRA     FW       Marseille  18.0   1       0  0.0
# 21  Joshua Acheampong  eng ENG     DF         Chelsea  18.0   2       2  1.8
# 35   Vasilije AdÅ¾iÄ‡   me MNE  MF,FW        Juventus  18.0   3       0  0.3
# 40     Asher Agbinone  eng ENG     MF  Crystal Palace  19.0   2       0  0.1
# 41    Jeremy Agbonifo   se SWE  FW,MF            Lens  19.0   2       0  0.8
#
#     Gls  Ast  TklW  Tkl+Int  KP   Cmp%
# 4     0    0     1        1   0  100.0
# 21    0    0     1        3   0   82.9
# 35    0    0     2        2   0   75.0
# 40    0    0     1        2   1   66.7
# 41    1    0     2        3   0   75.0
# Shape of the DataFrame after filtering by age: (320, 14)

# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.91.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %% [markdown]
# **Accessing your API key and using the OpenAI API**
#
# Make sure you have stored your OpenAI API key in Colab's Secrets Manager with the name `OPENAI_API_KEY`.

# %%
import openai
from google.colab import userdata
import pandas as pd

# Access the API key from Colab's Secrets Manager
openai.api_key = userdata.get('OPENAI_API_KEY')

# Prepare the data to be sent to the API
# We can use the filtered dataframe df_under_20 as it is more relevant for finding rising stars
data_for_prompt = df_under_20.to_markdown(index=False)

# Construct the prompt for the OpenAI model
prompt = f"""
You are a data analyst for a top European football club that is looking to recruit new talent for the upcoming season.
The club has provided you with the following football players stats dataset (limited to players under 20):

{data_for_prompt}

Your task is to select three players from this data who could be considered undervalued players or rising stars.
Please identify these three players by their name and ranking ('Rk' column if it were available in the filtered data, since it's not, just use Player name and Squad).
For each selected player, provide a brief justification (1-2 sentences) explaining why they might be a rising star or an undervalued player based on the provided stats.
"""

try:
    # Make the API call
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",  # Or another suitable model
        messages=[
            {"role": "system", "content": "You are a helpful data analyst assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=500,
        temperature=0.7,
    )

    # Print the response from the API
    print(response.choices[0].message.content)

except Exception as e:
    print(f"An error occurred: {e}")
